# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
X
# Out:
# array([[-0.0662987 ],
#        [ 1.1537182 ],
#        [-0.02813623],
#        [ 0.83030648],
#        [-2.5670001 ],
#        [ 0.31489123],
#        [-0.53350814],
#        [-0.92403913],
#        [ 1.97099211],
#        [ 0.50064309],
#        [-0.8276926 ],
#        [-0.81314699],
#        [-0.49624305],
#        [ 0.05746694],
#        [-0.13252345],
#        [ 0.37024606],
#        [ 0.84697333],
#        [ 0.41164548],
#        [-0.5013801 ],
#        [ 0.50332667],
#        [-0.69254915],
#        [-1.33524405],
#        [-1.86031492],
#        [ 0.37531012],
#        [-0.19304239],
#        [ 0.55823335],
#        [-0.04964759],
#        [-0.29872395],
#        [-0.2671804 ],
#        [-0.54289199],
#        [ 1.77841104],
#        [-1.44967535],
#        [ 0.82385737],
#        [-0.49076451],
#        [-0.6553432 ],
#        [-0.54895651],
#        [ 2.32374514],
#        [ 0.83249561],
#        [-1.8852171 ],
#        [-2.35061642],
#        [ 0.2667522 ],
#        [-1.97277497],
#        [-0.86969309],
#        [-0.78299372],
#        [ 0.13211589],
#        [-1.34442395],
#        [ 1.39664528],
#        [ 1.11702302],
#        [-0.50967863],
#        [-0.08994949],
#        [ 0.46895604],
#        [ 1.65531711],
#        [-2.72915122],
#        [-0.2411064 ],
#        [ 0.5579127 ],
#        [-0.77178873],
#        [ 0.79745035],
#        [ 0.27330859],
#        [ 0.24373584],
#        [ 1.79852665],
#        [ 0.30765263],
#        [-0.46298217],
#        [ 0.91925501],
#        [-0.16956439],
#        [ 0.08085487],
#        [-0.05825567],
#        [-2.29182519],
#        [ 0.31139117],
#        [ 0.45167666],
#        [-1.57193113],
#        [-0.98975356],
#        [ 0.23107724],
#        [-0.2344165 ],
#        [-1.79435325],
#        [ 1.12736644],
#        [ 0.68611743],
#        [-0.18277528],
#        [ 0.34379087],
#        [-0.23793351],
#        [ 1.46325748],
#        [ 0.01135858],
#        [-1.02643817],
#        [ 0.84908455],
#        [-0.33658902],
#        [ 0.73435393],
#        [-0.95850485],
#        [ 0.0308401 ],
#        [ 1.9379598 ],
#        [-1.06214121],
#        [-0.29313153],
#        [ 0.50979714],
#        [-0.92683559],
#        [ 1.14865479],
#        [ 0.46789705],
#        [-0.97425481],
#        [-0.40275633],
#        [ 1.11250224],
#        [-0.44089934],
#        [ 0.83556195],
#        [ 0.34845434]])

# %%
y
# Out:
# array([ -31.95385762,   79.89157849,    8.73151028,    2.36142097,
#        -160.00102179,   35.36134927,  -28.12703308,  -23.46785112,
#         114.54791101,    3.28328848,  -16.19942724,  -52.44341491,
#         -37.17974415,    1.28855274,   18.8424932 ,   68.93906348,
#          64.00510211,   41.89334047,   -3.73054249,   23.61687256,
#         -10.56401582,  -97.46989785, -111.57699031,   -0.96999518,
#          24.23702549,   30.56627104,    7.31355031,    0.80489754,
#         -12.42399331,  -31.08325807,   81.33059112,  -60.17516421,
#          45.09111345,  -36.57544246,   10.39038013,  -31.94102825,
#         129.66602546,   60.1692612 , -100.42261148, -146.10150282,
#          34.19875311,  -66.91658831,  -48.0718571 ,  -51.95124079,
#           7.78371319,  -75.91319068,   67.14900023,   83.27189548,
#         -12.19875451,   10.22964663,   54.79085447,   84.66480811,
#        -124.5681096 ,  -16.24850696,   15.26621748,  -53.88521566,
#          40.50816041,   38.06777217,    4.46048182,   81.59786436,
#          -4.48408796,  -28.84502158,   24.57833077,    4.61524598,
#         -17.68868359,    8.6170578 , -148.34329809,    4.47476383,
#          25.80206246,  -49.54518306,  -16.6853436 ,   16.98707363,
#         -21.43424113, -137.74131332,   56.6879575 ,   47.6882871 ,
#           3.87242023,   -2.71704921,  -10.11798495,   76.96565814,
#         -34.83351057,  -49.01193218,   74.86095784,  -18.73878428,
#          28.8893841 ,  -68.78228414,    7.35662206,   84.74699829,
#         -30.6753893 ,    6.85671386,  -16.16167845,  -45.1319764 ,
#          32.33959602,   48.558412  ,  -33.18663232,   -3.37036655,
#          74.53385937,   12.79864528,   10.6016421 ,   35.2230343 ])

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
obj=LinearRegression()

# %%
obj.fit(X,y)
# Out:
# LinearRegression()

# %%
obj.coef_
# Out:
# array([51.83134245])

# %%
obj.intercept_
# Out:
# np.float64(2.4288787911914813)

# %%
m=51.83

# %%
class MyGDRegressor:
  def __init__(self,learning_rate,epochs):
    self.m=51.83
    self.b=-120
    self.lr=learning_rate
    self.epochs=epochs
  def fit(self,x,y):
    #calculate b using Gradient descent
    for i in range(self.epochs):
      loss_slope=-2*np.sum(y-self.m*x.ravel()-self.b)
      self.b=self.b-(self.lr*loss_slope)
    print(self.b)

# %%
myObj=MyGDRegressor(0.001,50)

# %%
myObj.fit(X,y)
# Out:
# 2.427037885360799
